# %%
import sys  
sys.path.insert(0, r'\Users\marci\Desktop\Python\NIST_Database_webscraping')

# %%
from NIST_Line import NIST_Line

# %%
lines_Ar = NIST_Line(element='Ar', low_w=200, upper_w=900, sp_num=[1,2,3])

# %%
lines_Ar.search_n_nearest_lines(811, 10)
# Out:
#   element  sp_num  obs_wl_air(nm)  unc_obs_wl  ritz_wl_air(nm)  unc_ritz_wl  \
# 0      Ar       1       811.53110     0.00100       811.531100     0.001000
# 1      Ar       1       810.36930     0.00100       810.369200     0.001000
# 2      Ar       2       810.36931     0.00002       810.368610     0.000040
# 3      Ar       1       805.33080     0.00100       805.330800     0.001000
# 4      Ar       2       804.37600     0.00200       804.374663     0.000026
# 5      Ar       2       816.54050     0.00080       816.539388     0.000027
# 6      Ar       2       804.43080     0.00080       804.430210     0.000026
# 7      Ar       2       811.06500     0.00200       811.065882     0.000027
# 8      Ar       2       808.37500     0.00200       808.376340     0.000140
# 9      Ar       2       815.06470     0.00080       815.064960     0.000130
#
#    intens     gA(s^-1)  Acc     Ei(cm-1)     Ek(cm-1)                 conf_i  \
# ...

# %%
lines_Ar_threshold = NIST_Line(element='Ar', low_w=200, upper_w=900, sp_num=[1,2,3], threshold=10)

# %%
lines_Ar_threshold.search_n_nearest_lines(811, 10)
# Out:
#   element  sp_num  obs_wl_air(nm)  unc_obs_wl  ritz_wl_air(nm)  unc_ritz_wl  \
# 0      Ar       1       811.53110     0.00100       811.531100      0.00100
# 1      Ar       1       801.47860     0.00100       801.478500      0.00100
# 2      Ar       1       810.36930     0.00100       810.369200      0.00100
# 3      Ar       1       800.61570     0.00100       800.615600      0.00100
# 4      Ar       1       794.81760     0.00100       794.817600      0.00100
# 5      Ar       1       840.82100     0.00100       840.820900      0.00100
# 6      Ar       2       810.36931     0.00002       810.368610      0.00004
# 7      Ar       1       826.45220     0.00100       826.452100      0.00100
# 8      Ar       1       839.22700     0.01000              NaN          NaN
# 9      Ar       2       801.75280     0.00010       801.752791      0.00002
#
#    intens     gA(s^-1)  Acc     Ei(cm-1)     Ek(cm-1)                 conf_i  \
# ...
